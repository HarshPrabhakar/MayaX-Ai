# %%
data_dir = r"C:\Users\Harshu\Downloads\archive (4)\content"

# %%
import torch
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from torchvision import transforms

# Define transform if not already defined (assuming basic transforms for images)
transform = transforms.Compose([
	transforms.Resize((224, 224)),
	transforms.ToTensor(),
])

dataset = datasets.ImageFolder(data_dir, transform=transform)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_data, test_data = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dataset = datasets.ImageFolder(data_dir, transform=transform)
#       2
#       3 train_size = int(0.8 * len(dataset))
#       4 test_size = len(dataset) - train_size
#
# NameError: name 'datasets' is not defined
